# %% [markdown]
# # Introduction
# In this challenge, Santander invites Kagglers to help them identify which customers will make a specific transaction in the future, irrespective of the amount of money transacted. The data provided for this competition has the same structure as the real data they have available to solve this problem.
#
# The data is anonimyzed, each row containing 200 numerical values identified just with a number.
#
# Data: https://www.kaggle.com/c/santander-customer-transaction-prediction/overview/evaluation
#
# Reference Link: https://www.youtube.com/watch?v=LEWpRlaEJO8

# %% [markdown]
# ## Business problem
# Based on the data given for every user we have to predict wheater the user will do the transaction in future or not.

# %% [markdown]
# ## ML problem question
# - This one is a classical Binary classification machine learing problem.
# - There are 2 classes in the target 0 and 1.
# - 0 means not do transaction and 1 means will do transaction.

# %% [markdown]
# ## Evaluation Metrix
# The Evaluation metrix is the AUC and we have to make sure to get AUC as high as possible.

# %% [markdown]
# ## Mounting the Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive/self_case_study_1
# Out:
# /content/drive/My Drive/self_case_study_1

# %% [markdown]
# ## Loading the data from the kaggle

# %%
# !wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3" --header="Accept-Language: en-GB,en-US;q=0.9,en;q=0.8" --header="Referer: https://www.kaggle.com/" "https://storage.googleapis.com/kaggle-competitions-data/kaggle/10385/298493/train.csv.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1575271319&Signature=MR8AlCGs9Whsd9zMt3Tm%2BEIWiLFt2ehTuwOOgU8qRb6aqSgRs0b3Vs%2FgKFzrLqbB%2BJYQYxB3sG2BWI0lOwFa5x7bvgAwsVbGd32E6W9JT%2B3uRjfuIDgx%2F%2FmON00MT8Uzx0d%2BADCWBPhbm%2FFCpeyrJLMcvMyC5YcHfAs77UN9wolOi3G9tVfs1UQO9KA7gRLXjVtPqqfDJD9fR6Cipcyhv4OCiNJlr%2FN835eyyLgii961FhYSrazlKZvK1xNW7KAZGB8OorFk3a8mdeXvUoGeYpdfzLEgp2jHr7QDrbWdomBbNBrI87kP1o3rwWpkx3%2BHTpxwei6hg2qa7y18z12zPg%3D%3D" -O "train.csv.zip" -c
# Out:
# --2019-11-29 07:32:38--  https://storage.googleapis.com/kaggle-competitions-data/kaggle/10385/298493/train.csv.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1575271319&Signature=MR8AlCGs9Whsd9zMt3Tm%2BEIWiLFt2ehTuwOOgU8qRb6aqSgRs0b3Vs%2FgKFzrLqbB%2BJYQYxB3sG2BWI0lOwFa5x7bvgAwsVbGd32E6W9JT%2B3uRjfuIDgx%2F%2FmON00MT8Uzx0d%2BADCWBPhbm%2FFCpeyrJLMcvMyC5YcHfAs77UN9wolOi3G9tVfs1UQO9KA7gRLXjVtPqqfDJD9fR6Cipcyhv4OCiNJlr%2FN835eyyLgii961FhYSrazlKZvK1xNW7KAZGB8OorFk3a8mdeXvUoGeYpdfzLEgp2jHr7QDrbWdomBbNBrI87kP1o3rwWpkx3%2BHTpxwei6hg2qa7y18z12zPg%3D%3D
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.203.128, 2607:f8b0:400e:c07::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.203.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 128240759 (122M) [application/zip]
# Saving to: ‘train.csv.zip’
#
# train.csv.zip       100%[===================>] 122.30M  90.3MB/s    in 1.4s
#
# 2019-11-29 07:32:39 (90.3 MB/s) - ‘train.csv.zip’ saved [128240759/128240759]

# %% [markdown]
# ## Extracting the data

# %%
!7z e train.csv.zip
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 128240759 bytes (123 MiB)
#
# Extracting archive: train.csv.zip
# --
# Path = train.csv.zip
# Type = zip
# Physical Size = 128240759
#
# Everything is Ok
#
# Size:       302133017
# Compressed: 128240759

# %%
ls
# Out:
# self_case_study_1.ipynb  train.csv  train.csv.zip

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Reading the data

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    ID_code  target    var_0   var_1  ...  var_196  var_197  var_198  var_199
# 0  train_0       0   8.9255 -6.7863  ...   7.8784   8.5635  12.7803  -1.0914
# 1  train_1       0  11.5006 -4.1473  ...   8.1267   8.7889  18.3560   1.9518
# 2  train_2       0   8.6093 -2.7457  ...  -6.5213   8.2675  14.7222   0.3965
# 3  train_3       0  11.0604 -2.1518  ...  -2.9275  10.2922  17.9697  -8.9996
# 4  train_4       0   9.8369 -1.4834  ...   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]

# %%
data_1 = data.pop('target')
data['target'] = data_1

# %%
data.head()
# Out:
#    ID_code    var_0   var_1    var_2  ...  var_197  var_198  var_199  target
# 0  train_0   8.9255 -6.7863  11.9081  ...   8.5635  12.7803  -1.0914       0
# 1  train_1  11.5006 -4.1473  13.8588  ...   8.7889  18.3560   1.9518       0
# 2  train_2   8.6093 -2.7457  12.0805  ...   8.2675  14.7222   0.3965       0
# 3  train_3  11.0604 -2.1518   8.9522  ...  10.2922  17.9697  -8.9996       0
# 4  train_4   9.8369 -1.4834  12.8746  ...   9.5031  17.9974  -8.8104       0
#
# [5 rows x 202 columns]

# %%
data.describe()
# Out:
#                var_0          var_1  ...        var_199         target
# count  200000.000000  200000.000000  ...  200000.000000  200000.000000
# mean       10.679914      -1.627622  ...      -3.326537       0.100490
# std         3.040051       4.050044  ...      10.438015       0.300653
# min         0.408400     -15.043400  ...     -38.852800       0.000000
# 25%         8.453850      -4.740025  ...     -11.208475       0.000000
# 50%        10.524750      -1.608050  ...      -2.819550       0.000000
# 75%        12.758200       1.358625  ...       4.836800       0.000000
# max        20.315000      10.376800  ...      28.500700       1.000000
#
# [8 rows x 201 columns]

# %% [markdown]
# ## Exploratory data analysis

# %%
data.to_csv('data.csv', index= False)

# %%
data['target'].value_counts()
# Out:
# 0    179902
# 1     20098
# Name: target, dtype: int64

# %%
# Check for the null value count
data.isnull().sum()
# Out:
# ID_code    0
# var_0      0
# var_1      0
# var_2      0
# var_3      0
#           ..
# var_196    0
# var_197    0
# var_198    0
# var_199    0
# target     0
# Length: 202, dtype: int64

# %%
# First check for the distributio of 0 and 1
ax = sns.countplot('target',data=data)
print("percentage of data belongs to 0 :", data['target'].value_counts()[0]*100/200000,"%")
print("percentage of data belongs to 1 :", data['target'].value_counts()[1]*100/200000,"%")
ax.plot()
# Out:
# percentage of data belongs to 0 : 89.951 %
# percentage of data belongs to 1 : 10.049 %
# []

# %% [markdown]
# ### Observation
# - The data is highly imbalanced by looking at the plot
# - Around 90% of data belongs to the target class 0 and only 10% of data belongs   target class 1

# %% [markdown]
# ### Checking th distriution of all the feature towards the target value
# - Since we have 200 features and they all were anomyzed we have to check all the feature distribution towards the target value.
#
# - For this we creat a function that gives us the distribution of each and every feature towards the target values.

# %%
# sns.kdeplot(data['var_0'])
import matplotlib.pyplot as plt

def feature_distribution(data_1,data_2,target_0,target_1,features_list):
    sns.set_style('whitegrid')
    plt.figure()
    fig, ax = plt.subplots(10,10,figsize=(18,22))
    # plt.title('Distribution for the features first 100 features')   
    for  plot_count, feature in enumerate(features_list):
        plt.subplot(10,10,plot_count+1)
        sns.distplot(data_1[feature], hist=False,label=target_0)
        sns.distplot(data_2[feature], hist=False,label=target_1)
        plt.xlabel(feature, fontsize=9)
        locs, labels = plt.xticks()
        plt.tick_params(axis='x', which='major', labelsize=6, pad=-6)
        plt.tick_params(axis='y', which='major', labelsize=6)
    plt.show();

## Dstribution for the first 100 features
target_0_data = data.loc[data['target'] == 0]
target_1_data = data.loc[data['target'] == 1]
features = data.columns.values[1:101]
feature_distribution(target_0_data, target_1_data, '0', '1', features)

# %%
## Dstribution for the rest 100 features
features = data.columns.values[101:199]
feature_distribution(target_0_data, target_1_data, '0', '1', features)

# %% [markdown]
# ### Observations
# - By looking at the distribution of each feature towards the target values
# I found that most of the features have different distribution for the target values.
# - We can also day that there are some features that are quite close to normal distribution not completely but a little
# - Hence I can say that there are some kind o precessing is done on the data

# %% [markdown]
# ### Lets check the distribution of mean and std of the data

# %%
plt.figure(figsize=(16,6))
features = data.columns.values[1:202]
plt.title("Distribution of mean values per row in the data")
sns.distplot(data[features].mean(axis=1),color="green", kde=True,bins=120)
plt.show()

# %% [markdown]
#  From the graph the mean is around 6.7342 as row data

# %%
(data[features].mean(axis=1)).mean()
# Out:
# 6.7342799035497185

# %%
plt.figure(figsize=(16,6))
features = data.columns.values[1:202]
plt.title("Distribution of mean values per col in the data")
sns.distplot(data[features].mean(axis=0),color="green", kde=True,bins=120)
plt.show()

# %%
plt.figure(figsize=(16,6))
features = data.columns.values[1:202]
plt.title("Distribution of std values per row in the data")
sns.distplot(data[features].std(axis=1),color="black", kde=True,bins=120)
plt.show()

# %%
plt.figure(figsize=(16,6))
features = data.columns.values[1:202]
plt.title("Distribution of std values per col in the data")
sns.distplot(data[features].std(axis=0),color="black", kde=True,bins=120)
plt.show()

# %% [markdown]
# ### Distribution of the mean value dataset, grouped by value of target.

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per row in the data set")
sns.distplot(target_0_data[features].mean(axis=1),color="red", kde=True,bins=120, label='target = 0')
sns.distplot(target_1_data[features].mean(axis=1),color="black", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per col in the data set")
sns.distplot(target_0_data[features].mean(axis=0),color="red", kde=True,bins=120, label='target = 0')
sns.distplot(target_1_data[features].mean(axis=0),color="black", kde=True,bins=120, label='target = 1')
plt.legend(); plt.show()

# %% [markdown]
# ## Distribution of min and max value in data as row and col both wise

# %%
plt.figure(figsize=(16,6))
features = data.columns.values[1:202]
plt.title("Distribution of min values per row in the data")
sns.distplot(data[features].min(axis=1),color="green", kde=True,bins=120)
plt.show()

# %%
plt.figure(figsize=(16,6))
features = data.columns.values[1:202]
plt.title("Distribution of min values per col in the data")
sns.distplot(data[features].min(axis=0),color="green", kde=True,bins=120)
plt.show()

# %% [markdown]
# ### Observation
# - we have observed the lower value i.e -80 as the longer queue is at the lower side .
# - There is no difference between the min value as per row and col

# %%
plt.figure(figsize=(16,6))
features = data.columns.values[1:202]
plt.title("Distribution of max values per row in the data")
sns.distplot(data[features].max(axis=1),color="green", kde=True,bins=120)
plt.show()

# %%
plt.figure(figsize=(16,6))
features = data.columns.values[1:202]
plt.title("Distribution of max values per col in the data")
sns.distplot(data[features].max(axis=0),color="green", kde=True,bins=120)
plt.show()

# %% [markdown]
# ### Observation
# - we have observed the value value of around 73 or 74 as the max value
# - These value are same for both row and col

# %%
data.shape
# Out:
# (200000, 202)

# %%
(data[features].max(axis=1)).max()
# Out:
# 74.0321

# %% [markdown]
# ### Now let's check the correation between the features

# %%
features = data.columns.values[1:200]
cor_data = data[features].corr().abs().unstack().sort_values(kind="quicksort").reset_index()
cor_data = cor_data[cor_data['level_0'] != cor_data['level_1']]
# cor_data.head(10)

# %% [markdown]
# #### some most correlated data

# %%
cor_data.tail(10)
# Out:
#        level_0  level_1         0
# 39392  var_183  var_189  0.009359
# 39393  var_189  var_183  0.009359
# 39394   var_81  var_174  0.009490
# 39395  var_174   var_81  0.009490
# 39396  var_165   var_81  0.009714
# 39397   var_81  var_165  0.009714
# 39398  var_148   var_53  0.009788
# 39399   var_53  var_148  0.009788
# 39400  var_139   var_26  0.009844
# 39401   var_26  var_139  0.009844

# %% [markdown]
# #### some least correlated data

# %%
cor_data.head(10)
# Out:
#    level_0  level_1             0
# 0   var_75  var_191  2.703975e-08
# 1  var_191   var_75  2.703975e-08
# 2  var_173    var_6  5.942735e-08
# 3    var_6  var_173  5.942735e-08
# 4  var_109  var_126  1.313947e-07
# 5  var_126  var_109  1.313947e-07
# 6  var_144   var_27  1.772502e-07
# 7   var_27  var_144  1.772502e-07
# 8  var_100  var_177  3.116544e-07
# 9  var_177  var_100  3.116544e-07
